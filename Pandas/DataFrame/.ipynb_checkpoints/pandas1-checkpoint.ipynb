# %%
import pandas as pd

# %%
df_population_data = pd.read_csv('data.csv',encoding='shift-jis')

# %%
df_population_data
# Out:
#                                                都道府県コード 都道府県名   元号  和暦（年）  \
# 0                                                   00    全国   大正    9.0
# 1                                                   01   北海道   大正    9.0
# 2                                                   02   青森県   大正    9.0
# 3                                                   03   岩手県   大正    9.0
# 4                                                   04   宮城県   大正    9.0
# ..                                                 ...   ...  ...    ...
# 977                                                 45   宮崎県   平成   27.0
# 978                                                 46  鹿児島県   平成   27.0
# 979                                                 47   沖縄県   平成   27.0
# 980                         1)　沖縄県は調査されなかったため，含まれていない。   NaN  NaN    NaN
# 981  2)　長野県西筑摩群山口村と岐阜県中津川市の境界紛争地域人口（男39人，女34人）は全国に含...   NaN  NaN    NaN
#
#       西暦（年）    注    人口（総数）     人口（男）     人口（女）
# ...

# %%
type(df_population_data)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.set_option('display.max_rows',1000) #最大表示行数

# %%
df_population_data
# Out:
#                                                都道府県コード        都道府県名   元号  \
# 0                                                   00           全国   大正
# 1                                                   01          北海道   大正
# 2                                                   02          青森県   大正
# 3                                                   03          岩手県   大正
# 4                                                   04          宮城県   大正
# 5                                                   05          秋田県   大正
# 6                                                   06          山形県   大正
# 7                                                   07          福島県   大正
# 8                                                   08          茨城県   大正
# 9                                                   09          栃木県   大正
# 10                                                  10          群馬県   大正
# 11                                                  11          埼玉県   大正
# ...

# %%
pd.reset_option('display.max_rows')

# %%
df_population_data
# Out:
#                                                都道府県コード 都道府県名   元号  和暦（年）  \
# 0                                                   00    全国   大正    9.0
# 1                                                   01   北海道   大正    9.0
# 2                                                   02   青森県   大正    9.0
# 3                                                   03   岩手県   大正    9.0
# 4                                                   04   宮城県   大正    9.0
# ..                                                 ...   ...  ...    ...
# 977                                                 45   宮崎県   平成   27.0
# 978                                                 46  鹿児島県   平成   27.0
# 979                                                 47   沖縄県   平成   27.0
# 980                         1)　沖縄県は調査されなかったため，含まれていない。   NaN  NaN    NaN
# 981  2)　長野県西筑摩群山口村と岐阜県中津川市の境界紛争地域人口（男39人，女34人）は全国に含...   NaN  NaN    NaN
#
#       西暦（年）    注    人口（総数）     人口（男）     人口（女）
# ...

# %%
pd.set_option('display.max_columns',5) #最大表示行数

# %%
df_population_data
# Out:
#                                                都道府県コード 都道府県名  ...     人口（男）  \
# 0                                                   00    全国  ...  28044185
# 1                                                   01   北海道  ...   1244322
# 2                                                   02   青森県  ...    381293
# 3                                                   03   岩手県  ...    421069
# 4                                                   04   宮城県  ...    485309
# ..                                                 ...   ...  ...       ...
# 977                                                 45   宮崎県  ...    519242
# 978                                                 46  鹿児島県  ...    773061
# 979                                                 47   沖縄県  ...    704619
# 980                         1)　沖縄県は調査されなかったため，含まれていない。   NaN  ...       NaN
# 981  2)　長野県西筑摩群山口村と岐阜県中津川市の境界紛争地域人口（男39人，女34人）は全国に含...   NaN  ...       NaN
#
#         人口（女）
# 0    27918868
# 1     1114861
# ...

# %%
pd.reset_option('display.max_columns')

# %%
df_population_data
# Out:
#                                                都道府県コード 都道府県名   元号  和暦（年）  \
# 0                                                   00    全国   大正    9.0
# 1                                                   01   北海道   大正    9.0
# 2                                                   02   青森県   大正    9.0
# 3                                                   03   岩手県   大正    9.0
# 4                                                   04   宮城県   大正    9.0
# ..                                                 ...   ...  ...    ...
# 977                                                 45   宮崎県   平成   27.0
# 978                                                 46  鹿児島県   平成   27.0
# 979                                                 47   沖縄県   平成   27.0
# 980                         1)　沖縄県は調査されなかったため，含まれていない。   NaN  NaN    NaN
# 981  2)　長野県西筑摩群山口村と岐阜県中津川市の境界紛争地域人口（男39人，女34人）は全国に含...   NaN  NaN    NaN
#
#       西暦（年）    注    人口（総数）     人口（男）     人口（女）
# ...

# %%
df_population_data.head() #最初の行　デフォは５行
# Out:
#   都道府県コード 都道府県名  元号  和暦（年）   西暦（年）    注    人口（総数）     人口（男）     人口（女）
# 0      00    全国  大正    9.0  1920.0  NaN  55963053  28044185  27918868
# 1      01   北海道  大正    9.0  1920.0  NaN   2359183   1244322   1114861
# 2      02   青森県  大正    9.0  1920.0  NaN    756454    381293    375161
# 3      03   岩手県  大正    9.0  1920.0  NaN    845540    421069    424471
# 4      04   宮城県  大正    9.0  1920.0  NaN    961768    485309    476459

# %%
df_population_data.head(10) #最初の行
# Out:
#   都道府県コード 都道府県名  元号  和暦（年）   西暦（年）    注    人口（総数）     人口（男）     人口（女）
# 0      00    全国  大正    9.0  1920.0  NaN  55963053  28044185  27918868
# 1      01   北海道  大正    9.0  1920.0  NaN   2359183   1244322   1114861
# 2      02   青森県  大正    9.0  1920.0  NaN    756454    381293    375161
# 3      03   岩手県  大正    9.0  1920.0  NaN    845540    421069    424471
# 4      04   宮城県  大正    9.0  1920.0  NaN    961768    485309    476459
# 5      05   秋田県  大正    9.0  1920.0  NaN    898537    453682    444855
# 6      06   山形県  大正    9.0  1920.0  NaN    968925    478328    490597
# 7      07   福島県  大正    9.0  1920.0  NaN   1362750    673525    689225
# 8      08   茨城県  大正    9.0  1920.0  NaN   1350400    662128    688272
# 9      09   栃木県  大正    9.0  1920.0  NaN   1046479    514255    532224

# %%
df_population_data.tail(10) #最後の行
# Out:
#                                                都道府県コード 都道府県名   元号  和暦（年）  \
# 972                                                 40   福岡県   平成   27.0
# 973                                                 41   佐賀県   平成   27.0
# 974                                                 42   長崎県   平成   27.0
# 975                                                 43   熊本県   平成   27.0
# 976                                                 44   大分県   平成   27.0
# 977                                                 45   宮崎県   平成   27.0
# 978                                                 46  鹿児島県   平成   27.0
# 979                                                 47   沖縄県   平成   27.0
# 980                         1)　沖縄県は調査されなかったため，含まれていない。   NaN  NaN    NaN
# 981  2)　長野県西筑摩群山口村と岐阜県中津川市の境界紛争地域人口（男39人，女34人）は全国に含...   NaN  NaN    NaN
#
#       西暦（年）    注   人口（総数）    人口（男）    人口（女）
# 972  2015.0  NaN  5101556  2410418  2691138
# 973  2015.0  NaN   832832   393073   439759
# ...

# %%
df_population_data.sample(10) #ランダム
# Out:
#     都道府県コード 都道府県名  元号  和暦（年）   西暦（年）    注   人口（総数）    人口（男）    人口（女）
# 203      11   埼玉県  昭和   15.0  1940.0  NaN  1608039   798321   809718
# 658      26   京都府  昭和   60.0  1985.0  NaN  2586574  1264035  1322539
# 651      19   山梨県  昭和   60.0  1985.0  NaN   832832   407910   424922
# 264      24   三重県  昭和   20.0  1945.0   1)  1394286   646954   747332
# 619      37   香川県  昭和   55.0  1980.0  NaN   999864   481104   518760
# 272      32   島根県  昭和   20.0  1945.0   1)   860275   395360   464915
# 770      38   愛媛県  平成    7.0  1995.0  NaN  1506700   712518   794182
# 734      02   青森県  平成    7.0  1995.0  NaN  1481663   704189   777474
# 702      20   長野県  平成    2.0  1990.0  NaN  2156627  1048109  1108518
# 967      35   山口県  平成   27.0  2015.0  NaN  1404729   665008   739721

# %%
df_population_data.info() #情報表示
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 982 entries, 0 to 981
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   都道府県コード  982 non-null    object
#  1   都道府県名    980 non-null    object
#  2   元号       980 non-null    object
#  3   和暦（年）    980 non-null    float64
#  4   西暦（年）    980 non-null    float64
#  5   注        96 non-null     object
#  6   人口（総数）   980 non-null    object
#  7   人口（男）    980 non-null    object
#  8   人口（女）    980 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 69.2+ KB

# %%
df_population_data.describe() #統計量
# Out:
#             和暦（年）        西暦（年）
# count  980.000000   980.000000
# mean    25.095918  1968.010204
# std     17.012192    28.841611
# min      2.000000  1920.000000
# 25%     12.000000  1945.000000
# 50%     22.000000  1970.000000
# 75%     40.000000  1995.000000
# max     60.000000  2015.000000

# %%
df_population_data.describe().round(0)
# Out:
#        和暦（年）   西暦（年）
# count  980.0   980.0
# mean    25.0  1968.0
# std     17.0    29.0
# min      2.0  1920.0
# 25%     12.0  1945.0
# 50%     22.0  1970.0
# 75%     40.0  1995.0
# max     60.0  2015.0
